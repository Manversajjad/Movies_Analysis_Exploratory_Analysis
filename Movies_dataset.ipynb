# %% [markdown]
# <a href="https://colab.research.google.com/github/Manversajjad/Movies_Analysis_Exploratory_Analysis/blob/main/Movies_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comprehension - I

# %% [markdown]
# Consider that you are a data analyst for Amazon Prime. The management wants you to analyze the 100 top-rated movies of the past decade using information about the movies, their actors, their genres, and who rated them online.<br><br>
#
# Answer these questions:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
d = pd.read_csv(r'/content/Movie+Assignment+Data.csv')
d.head()
# Out:
#                    Title  title_year     budget      Gross      actor_1_name  \
# 0             La La Land        2016   30000000  151101803      Ryan Gosling
# 1               Zootopia        2016  150000000  341268248  Ginnifer Goodwin
# 2                   Lion        2016   12000000   51738905         Dev Patel
# 3                Arrival        2016   47000000  100546139         Amy Adams
# 4  Manchester by the Sea        2016    9000000   47695371     Casey Affleck
#
#          actor_2_name     actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone       Amiée Conn                   14000
# 1       Jason Bateman       Idris Elba                    2800
# 2       Nicole Kidman      Rooney Mara                   33000
# 3       Jeremy Renner  Forest Whitaker                   35000
# 4  Michelle Williams     Kyle Chandler                     518
#
#    actor_2_facebook_likes  actor_3_facebook_likes  ...  Votes3044M Votes3044F  \
# 0                 19000.0                     NaN  ...         7.9        7.8
# 1                 28000.0                 27000.0  ...         7.8        8.1
# 2                 96000.0                  9800.0  ...         7.9        8.2
# 3                  5300.0                     NaN  ...         7.8        7.8
# 4                 71000.0                  3300.0  ...         7.7        7.7
#
#   Votes45A Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  content_rating  \
# 0      7.6       7.6        7.5        7.1      8.3       8.1           PG-13
# 1      7.8       7.8        8.1        7.6      8.0       8.0              PG
# 2      8.0       7.9        8.4        7.1      8.1       8.0           PG-13
# 3      7.6       7.6        7.7        7.3      8.0       7.9           PG-13
# 4      7.6       7.6        7.6        7.1      7.9       7.8               R
#
#      Country
# 0        USA
# 1        USA
# 2  Australia
# 3        USA
# 4        USA
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Problem - I
# Of the three movie genres, consider only the first one as the original genre. Between 2010 and 2016, which were the most common and least common movie genres, respectively?<br><br>
#
# a.   Action and mystery<br>
# b.   Drama and animation<br>
# c.   Drama and comedy<br>
# d.   Adventure and biography

# %%
movie_pivoted = pd.pivot_table(data=d, index=['title_year'],
columns=['genre_1'], values='IMDb_rating', aggfunc=len)

ax = sns.heatmap(data=movie_pivoted, cmap="Greens", annot=True)

# %% [markdown]
# ## Problem - II
# Of the three movie genres, consider only the first one as the original genre of a movie. Which was the most popular genre in 2013?<br><br>
#
# a.   Biography<br>
# b.   Drama<br>
# c.   Action<br>
# d.   Comedy

# %%
movie_pivoted = pd.pivot_table(data=d, index=['title_year'],
columns=['genre_1'], values='IMDb_rating', aggfunc=len)

ax = sns.heatmap(data=movie_pivoted, cmap="Greens",annot=True)
plt.show()

# %% [markdown]
# ## Problem - III
# You want to see how a movie’s budget impacts the gross earned from sales. What is the relationship between these two factors?<br><br>
#
# a.   Gross has a positive correlation with the budget of a movie.<br>
# b.   Gross has a negative correlation with the budget of a movie.<br>
# c.   Gross does not depend on the budget of a movie.<br>
# d.   None of the above.

# %%
scatter_u = sns.scatterplot(data = d, x="Gross", y="budget")

# %%
scatter_u = sns.regplot(data = d, x="budget", y="Gross")
